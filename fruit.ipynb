# %% [markdown]
# <a href="https://www.kaggle.com/code/hunhun2211/fruit?scriptVersionId=96098206" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#import library
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from keras.utils import np_utils
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/fruitdata/fruit',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='../input/fruitdata/fruit',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 80 images belonging to 10 classes.
# Found 19 images belonging to 10 classes.

# %%
# X_train.shape, y_train.shape,X_test.shape,y_test.shape
train_dataset.classes
train_dataset.class_indices
# Out:
# {'apple': 0,
#  'banana': 1,
#  'carrot': 2,
#  'grapes': 3,
#  'lemon': 4,
#  'mango': 5,
#  'orange': 6,
#  'pineapple': 7,
#  'potato': 8,
#  'tomato': 9}

# %%
import numpy as np  #
import pandas as pd # xu ly mang
import seaborn as sns # do thi
import matplotlib.pyplot as plt # ve do hoa
from sklearn.preprocessing import StandardScaler  # xu ly du lieu , du lieu k dong deu
from sklearn.model_selection import train_test_split # chia du lieu 
from keras.layers import Dense,Activation,Dropout,BatchNormalization,LSTM #  :batch... : chuan cua ANN
from keras.models import Sequential 
from tensorflow.keras.utils import to_categorical #  de dam bao do hcinh xac cao 
from keras import callbacks #
from sklearn .metrics import  precision_score,recall_score, confusion_matrix, classification_report, accuracy_score,f1_score # thu vien cho do luong

# %%
# Tạo mô hinh
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
# Out:
# 2022-05-20 07:31:24.983252: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:31:25.115261: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:31:25.116270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:31:25.117567: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-20 07:31:25.117937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:31:25.118790: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:31:25.119540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:31:27.434068: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:31:27.435123: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:31:27.435937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 07:31:27.437411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# Dùng CNN tách biên và giờ quay trở loại ANN để phân loại
from keras.layers.convolutional import Conv2D, MaxPooling2D

from keras.layers import Dense, Activation, Flatten


model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 5,596,842
# Trainable params: 5,596,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])

# %%
history=model.fit(train_dataset,batch_size=32,epochs=50,verbose=1,validation_data=validation_dataset)
# Out:
# 2022-05-20 07:31:29.430397: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-05-20 07:31:32.363945: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 8/8 [==============================] - 16s 1s/step - loss: 2.7420 - accuracy: 0.0625 - val_loss: 2.3631 - val_accuracy: 0.0526
# Epoch 2/50
# 8/8 [==============================] - 6s 856ms/step - loss: 2.3824 - accuracy: 0.1125 - val_loss: 2.2209 - val_accuracy: 0.1053
# Epoch 3/50
# 8/8 [==============================] - 6s 770ms/step - loss: 2.2440 - accuracy: 0.2125 - val_loss: 2.2054 - val_accuracy: 0.1579
# Epoch 4/50
# 8/8 [==============================] - 6s 843ms/step - loss: 2.0955 - accuracy: 0.2750 - val_loss: 2.0992 - val_accuracy: 0.3158
# Epoch 5/50
# 8/8 [==============================] - 7s 848ms/step - loss: 2.0001 - accuracy: 0.2625 - val_loss: 1.9835 - val_accuracy: 0.2632
# Epoch 6/50
# 8/8 [==============================] - 6s 801ms/step - loss: 1.8502 - accuracy: 0.3875 - val_loss: 1.8151 - val_accuracy: 0.3684
# Epoch 7/50
# 8/8 [==============================] - 6s 827ms/step - loss: 1.6029 - accuracy: 0.4625 - val_loss: 1.7697 - val_accuracy: 0.3684
# Epoch 8/50
# 8/8 [==============================] - 6s 805ms/step - loss: 1.4773 - accuracy: 0.4750 - val_loss: 1.7520 - val_accuracy: 0.3684
# Epoch 9/50
# 8/8 [==============================] - 7s 896ms/step - loss: 1.2300 - accuracy: 0.6750 - val_loss: 1.6507 - val_accuracy: 0.2632
# Epoch 10/50
# 8/8 [==============================] - 6s 848ms/step - loss: 0.9361 - accuracy: 0.6750 - val_loss: 1.7203 - val_accuracy: 0.3158
# Epoch 11/50
# 8/8 [==============================] - 6s 681ms/step - loss: 0.8269 - accuracy: 0.7250 - val_loss: 1.7110 - val_accuracy: 0.4737
# Epoch 12/50
# 8/8 [==============================] - 6s 759ms/step - loss: 0.9656 - accuracy: 0.7125 - val_loss: 2.0191 - val_accuracy: 0.4211
# Epoch 13/50
# 8/8 [==============================] - 6s 859ms/step - loss: 0.8799 - accuracy: 0.7125 - val_loss: 1.4382 - val_accuracy: 0.6316
# Epoch 14/50
# 8/8 [==============================] - 7s 799ms/step - loss: 0.5224 - accuracy: 0.8750 - val_loss: 1.3844 - val_accuracy: 0.6842
# Epoch 15/50
# 8/8 [==============================] - 6s 817ms/step - loss: 0.3832 - accuracy: 0.9000 - val_loss: 1.8239 - val_accuracy: 0.5789
# Epoch 16/50
# 8/8 [==============================] - 6s 777ms/step - loss: 0.3572 - accuracy: 0.8250 - val_loss: 1.3428 - val_accuracy: 0.6842
# Epoch 17/50
# 8/8 [==============================] - 7s 885ms/step - loss: 0.2887 - accuracy: 0.9250 - val_loss: 1.4560 - val_accuracy: 0.6316
# Epoch 18/50
# 8/8 [==============================] - 7s 840ms/step - loss: 0.2465 - accuracy: 0.9625 - val_loss: 1.4521 - val_accuracy: 0.6316
# Epoch 19/50
# 8/8 [==============================] - 7s 768ms/step - loss: 0.1793 - accuracy: 0.9500 - val_loss: 1.4987 - val_accuracy: 0.7368
# Epoch 20/50
# 8/8 [==============================] - 6s 859ms/step - loss: 0.1837 - accuracy: 0.9250 - val_loss: 1.5342 - val_accuracy: 0.5263
# Epoch 21/50
# 8/8 [==============================] - 6s 696ms/step - loss: 0.1349 - accuracy: 0.9500 - val_loss: 1.5184 - val_accuracy: 0.6842
# Epoch 22/50
# 8/8 [==============================] - 6s 784ms/step - loss: 0.0613 - accuracy: 0.9750 - val_loss: 1.4301 - val_accuracy: 0.5789
# Epoch 23/50
# 8/8 [==============================] - 7s 876ms/step - loss: 0.1101 - accuracy: 0.9625 - val_loss: 1.4096 - val_accuracy: 0.6316
# Epoch 24/50
# 8/8 [==============================] - 6s 775ms/step - loss: 0.0714 - accuracy: 0.9750 - val_loss: 1.7750 - val_accuracy: 0.6316
# Epoch 25/50
# 8/8 [==============================] - 6s 802ms/step - loss: 0.0967 - accuracy: 0.9375 - val_loss: 1.2399 - val_accuracy: 0.6842
# Epoch 26/50
# 8/8 [==============================] - 6s 849ms/step - loss: 0.1332 - accuracy: 0.9625 - val_loss: 1.6696 - val_accuracy: 0.6842
# Epoch 27/50
# 8/8 [==============================] - 6s 753ms/step - loss: 0.0822 - accuracy: 0.9875 - val_loss: 1.5747 - val_accuracy: 0.5789
# Epoch 28/50
# 8/8 [==============================] - 6s 830ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 1.6699 - val_accuracy: 0.5263
# Epoch 29/50
# 8/8 [==============================] - 6s 759ms/step - loss: 0.0416 - accuracy: 0.9875 - val_loss: 1.3836 - val_accuracy: 0.6842
# Epoch 30/50
# 8/8 [==============================] - 6s 794ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 1.9230 - val_accuracy: 0.6842
# Epoch 31/50
# 8/8 [==============================] - 6s 742ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 2.1898 - val_accuracy: 0.6842
# Epoch 32/50
# 8/8 [==============================] - 7s 870ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 1.7263 - val_accuracy: 0.6316
# Epoch 33/50
# 8/8 [==============================] - 6s 826ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 1.4418 - val_accuracy: 0.6316
# Epoch 34/50
# 8/8 [==============================] - 7s 913ms/step - loss: 0.0321 - accuracy: 0.9875 - val_loss: 1.9125 - val_accuracy: 0.5789
# Epoch 35/50
# 8/8 [==============================] - 6s 694ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 1.9035 - val_accuracy: 0.5789
# Epoch 36/50
# 8/8 [==============================] - 6s 680ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 1.5931 - val_accuracy: 0.5789
# Epoch 37/50
# 8/8 [==============================] - 6s 771ms/step - loss: 0.0194 - accuracy: 0.9875 - val_loss: 2.1524 - val_accuracy: 0.6316
# Epoch 38/50
# 8/8 [==============================] - 6s 757ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 1.9925 - val_accuracy: 0.6316
# Epoch 39/50
# 8/8 [==============================] - 7s 922ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.9216 - val_accuracy: 0.6316
# Epoch 40/50
# 8/8 [==============================] - 6s 792ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.8388 - val_accuracy: 0.6316
# Epoch 41/50
# 8/8 [==============================] - 6s 825ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.8677 - val_accuracy: 0.5789
# Epoch 42/50
# 8/8 [==============================] - 6s 825ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.9381 - val_accuracy: 0.5789
# Epoch 43/50
# 8/8 [==============================] - 6s 775ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 2.0253 - val_accuracy: 0.6316
# Epoch 44/50
# 8/8 [==============================] - 7s 849ms/step - loss: 0.0223 - accuracy: 0.9875 - val_loss: 2.5220 - val_accuracy: 0.6316
# Epoch 45/50
# 8/8 [==============================] - 6s 788ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 2.7925 - val_accuracy: 0.5263
# Epoch 46/50
# 8/8 [==============================] - 6s 768ms/step - loss: 0.0275 - accuracy: 0.9875 - val_loss: 2.2354 - val_accuracy: 0.5789
# Epoch 47/50
# 8/8 [==============================] - 6s 820ms/step - loss: 0.0217 - accuracy: 0.9875 - val_loss: 2.1004 - val_accuracy: 0.4737
# Epoch 48/50
# 8/8 [==============================] - 6s 773ms/step - loss: 0.1130 - accuracy: 0.9500 - val_loss: 1.9627 - val_accuracy: 0.6842
# Epoch 49/50
# 8/8 [==============================] - 7s 929ms/step - loss: 0.0715 - accuracy: 0.9750 - val_loss: 1.9684 - val_accuracy: 0.5263
# Epoch 50/50
# 8/8 [==============================] - 6s 782ms/step - loss: 0.0533 - accuracy: 0.9875 - val_loss: 1.1994 - val_accuracy: 0.5789

# %%
# vẽ lại quá trình học
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
#in sai so va do chinh xac
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  1.199398398399353
# Độ chính xác  0.5789473652839661

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/grape-test/grape_test.jpg"

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq= np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("apple")
if(kq==1):
    print("banana")
if(kq==2):
    print("carrot")
if(kq==3):
    print("grapes")
if(kq==4):
    print("lemon")
if(kq==5):
    print("mango")
if(kq==6):
    print("orange")
if(kq==7):
    print("pineapple")
if(kq==8):
    print("potato")
if(kq==9):
    print("tomato")
# Out:
# apple
